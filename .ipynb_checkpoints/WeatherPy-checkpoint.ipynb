# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

from api_keys import api_key

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %%
cities[0:10]
# Out:
# ['qaanaaq',
#  'airai',
#  'rikitea',
#  'puerto ayora',
#  'mandurah',
#  'tsabong',
#  'bage',
#  'broome',
#  'busselton',
#  'alofi']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
api_key = "912758434b6eac6b77d9044e5ce6c61b"
url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lon = []
max_temp = []
wind_speed = []

for city in cities:
    query_url = url + "appid=" + api_key + "&q=" + city + "&units=imperial"
    response = requests.get(query_url)
    if response.status_code == 200:
        print("Processing Record: " + city)
        response = response.json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp"])
        wind_speed.append(response["wind"]["speed"])
# Out:
# Processing Record: qaanaaq
# Processing Record: airai
# Processing Record: rikitea
# Processing Record: puerto ayora
# Processing Record: mandurah
# Processing Record: tsabong
# Processing Record: bage
# Processing Record: broome
# Processing Record: busselton
# Processing Record: alofi
# Processing Record: chokurdakh
# Processing Record: mar del plata
# Processing Record: thompson
# Processing Record: vaini
# Processing Record: bluff
# Processing Record: yellowknife
# Processing Record: albany
# Processing Record: dzhebariki-khaya
# Processing Record: synya
# Processing Record: georgetown
# Processing Record: hobart
# Processing Record: zhigansk
# Processing Record: jinchang
# Processing Record: kruisfontein
# Processing Record: vila velha
# Processing Record: clyde river
# Processing Record: toguchin
# Processing Record: kyra
# Processing Record: tuatapere
# Processing Record: hukuntsi
# Processing Record: hegra
# Processing Record: severo-kurilsk
# Processing Record: dikson
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({"City": city_name,
                           "Country": country,
                           "Cloudiness": cloudiness, 
                           "Date": date,
                           "Humidity": humidity,
                           "Lat": lat,
                           "Lon": lon,
                           "Max Temp": max_temp,
                           "Wind Speed": wind_speed
                          })
weather_df.head()
# Out:
#            City Country  Cloudiness        Date  Humidity    Lat     Lon  \
# 0       Qaanaaq      GL           0  1578922045        60  77.48  -69.36
# 1         Airai      TL         100  1578922045        86  -8.93  125.41
# 2       Rikitea      PF           1  1578922046        83 -23.12 -134.97
# 3  Puerto Ayora      EC           1  1578922046        81  -0.74  -90.35
# 4      Mandurah      AU           0  1578922046        77 -32.55  115.70
#
#    Max Temp  Wind Speed
# 0    -13.31        5.70
# 1     69.35        1.83
# 2     76.41       11.34
# 3     75.99        5.01
# 4     74.41        1.01

# %%
weather_df.to_csv("weather_by_city.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], facecolors="skyblue", edgecolors='black')
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("City Latitude")
plt.ylabel("Max Temperature")
plt.grid(True)
plt.show()
plt.savefig("lat_vs_temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"], facecolors="skyblue", edgecolors = "black")
plt.title("City Latitude vs. Humidity")
plt.xlabel("City Latitude")
plt.ylabel("Humidity")
plt.grid(True)
plt.show()
plt.savefig("lat_vs_hum.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], facecolors = "skyblue", edgecolors = "black")
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("City Latitude")
plt.ylabel("Humidity")
plt.grid(True)
plt.show()
plt.savefig("lat_vs_cloud.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], facecolors = "skyblue", edgecolors = "black")
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("City Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)
plt.show()
plt.savefig("lat_vs_wing.png")
